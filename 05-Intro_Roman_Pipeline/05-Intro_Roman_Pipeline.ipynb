# %% [markdown]
# ### Intro to the Roman Pipeline

# %% [markdown]
# #### Outline
#
# - Pipeline installation and setup
# - Running the pipeline
# - Exercise
# - CRDS
# - Feedback and discussion

# %% [markdown]
# ### Roman pipeline installation and setup up

# %% [markdown]
# The Roman pipeline package is a Python package, called `romancal`. The code is available on [GitHub](https://github.com/spacetelescope/romancal) and releases are posted on [PyPi](https://pypi.org/project/romancal/). Before running the Roman pipeline make sure `romancal` and all its dependencies are installed. The latest installation instructions are available in the [README](https://github.com/spacetelescope/romancal/blob/main/README.md) file on github, and briefly mentioned below.
#
# Public releases are installed directly from PyPI using
#
# ```
# % pip install romancal
# ```
# This installs the pipeline and all its dependencies in the current Python environment. We recommend to use conda as a basis for managing the environments and that new releases are installed in new conda environments.
#
# The development version of the pipeline can be installed using the command:
#
# ```
# % pip install git+https://github.com/spacetelescope/romancal.git
# ```
#
# This will install the code from the main development branch and all its current dependencies.
#
# In addition, we recommend that jupyter and ipython are installed as well. They are not dependencies, just convenience.
#
# The pipeline uses reference stored in the [Calibration Reference Data System (CRDS)](https://roman-crds.stsci.edu/). We don't have a public CRDS server for Roman yet so examples in this notebook while showing how to use a server when it is available, will use local reference files.
#
# **Pipeline documentation** is available publicly on [readthedocs](https://roman-pipeline.readthedocs.io/en/latest/).

# %% [markdown]
# #### CRDS configuration
#
# To run the pipeline outside the STScI network, CRDS must be configured by setting two environment variables:
#
# ```
# export CRDS_PATH=$HOME/crds_cache
# export CRDS_SERVER_URL=https://roman-crds.stsci.edu
# ```
#
# ### The CRDS variables need to be set in the environment before starting the notebook.

# %% [markdown]
# #### Running the Roman Pipeline
#
# The pipeline can be run on the command line or in a python session. We'll look first at how to run it in Python. But first, let's download some data.

# %% [markdown]
# #### Stages of the Roman pipeline
#
# The Roman calibration pipeline is split into three stages
#
# - Level2 pipeline, or Exposure Level Pipeline (ELP)
#
#   This stage runs on individual exposures and applies detector-level corrections to given exposure types (imaging, prism, and grism.). The currently implemented steps are listed [here](https://roman-pipeline.readthedocs.io/en/latest/roman/pipeline/exposure_pipeline.html#exposure-pipeline).
#
#
# - Level 3 pipeline, or High Level Pipeline (HLP)
#
#   The Level 3 pipeline combines individual exposures according to the association rules supplied. This is not implemented yet.
#
#
# - Level 4 pipeline - generates high level products, like various types of catalogs.

# %% [markdown]
# **Steps in a Pipeline stage**
#
# Every stage consistes of one or more steps which run in a sequence. The `ExposurePipeline` currently defines the following steps:
#
# ```
# step_defs = {'dq_init': dq_init_step.DQInitStep,
#              'saturation': SaturationStep,
#              "refpix": RefPixStep,
#              "linearity": LinearityStep,
#              "dark_current": DarkCurrentStep,
#              "rampfit": ramp_fit_step.RampFitStep,
#              "assign_wcs": AssignWcsStep,
#              "flatfield": FlatFieldStep,
#              "photom": PhotomStep,
#              "source_detection": SourceDetectionStep,
#              "tweakreg": TweakRegStep,
#             }
#
# ```

# %% [markdown]
# #### Data files naming conventions

# %% [markdown]
# File names are constructed using the following rules:
#
# **WFI detector Level 1 files**
#
# These are uncalibrated files, the standard suffix is `uncal`:
# ```
# rPPPPPCCAAASSSOOOVVV_ggsaa_eeee_<detector>_uncal.asdf
# ```
#
# **WFI detector Level 2 files**
#
# These are pixel calibrated files, the standard suffix is `cal`:
#
# ```
# rPPPPPCCAAASSSOOOVVV_ggsaa_eeee_<detector>_cal.asdf
# ```
#
# `PPPPP`: Program number
#
# `CC`:    Execution plan number
#
# `AAA`:   Pass number (with execution plan)
#
# `SSS`:   Segment Number (within pass)
#
# `OOO`:   Observation number
#
# `VVV`:   Visit number
#
# `gg`:    Group identifier
#
# `s`:     Sequence identifier (within the group)
#          1 for the prime exposure
#          > 1 for the parallel exposure
#
# `aa`:    Activity Identifier (within the sequence)
#
# `eeee`:  Exposure number (within the visit)

# %% [markdown]
# #### Running the ELP pipeline from a Python session

# %% [markdown]
# Using `call` is the recommended way to run the pipeline in a Python session. In this case the output data model is returned in memory and can be saved to disk either by passing an option to the `call` method or in a separate command:

# %%
from romancal.pipeline import ExposurePipeline
import os
os.environ["STPSF_PATH"] = os.getcwd()+"/../data/stpsf-data"

# %%
# Is there a way to pass a parameter to call?
out = ExposurePipeline.call('../data/r0000101001001001001_0001_wfi01_uncal.asdf',
                            save_results=True)
# Out:
# 2025-09-12 21:39:57,524 - CRDS - ERROR -  Error determining best reference for 'pars-dqinitstep'  =   No match found.
# 2025-09-12 21:39:57,525 - CRDS - ERROR -  Error determining best reference for 'pars-saturationstep'  =   No match found.
# 2025-09-12 21:39:57,526 - CRDS - ERROR -  Error determining best reference for 'pars-refpixstep'  =   No match found.
# 2025-09-12 21:39:57,526 - CRDS - ERROR -  Error determining best reference for 'pars-linearitystep'  =   No match found.
# 2025-09-12 21:39:57,527 - CRDS - ERROR -  Error determining best reference for 'pars-darkcurrentstep'  =   No match found.
# 2025-09-12 21:39:57,527 - CRDS - ERROR -  Error determining best reference for 'pars-rampfitstep'  =   No match found.
# 2025-09-12 21:39:57,528 - CRDS - ERROR -  Error determining best reference for 'pars-assignwcsstep'  =   No match found.
# 2025-09-12 21:39:57,529 - CRDS - ERROR -  Error determining best reference for 'pars-flatfieldstep'  =   No match found.
# 2025-09-12 21:39:57,529 - CRDS - ERROR -  Error determining best reference for 'pars-photomstep'  =   No match found.
# 2025-09-12 21:39:57,530 - CRDS - ERROR -  Error determining best reference for 'pars-sourcecatalogstep'  =   Unknown reference type 'pars-sourcecatalogstep'
# 2025-09-12 21:39:57,530 - CRDS - ERROR -  Error determining best reference for 'pars-tweakregstep'  =   No match found.
# 2025-09-12 21:39:57,531 - CRDS - ERROR -  Error determining best reference for 'pars-exposurepipeline'  =   No match found.
# 2025-09-12 21:39:57,536 - stpipe.ExposurePipeline - INFO - ExposurePipeline instance created.
# 2025-09-12 21:39:57,537 - stpipe.ExposurePipeline.dq_init - INFO - DQInitStep instance created.
# 2025-09-12 21:39:57,537 - stpipe.ExposurePipeline.saturation - INFO - SaturationStep instance created.
# 2025-09-12 21:39:57,538 - stpipe.ExposurePipeline.refpix - INFO - RefPixStep instance created.
# 2025-09-12 21:39:57,538 - stpipe.ExposurePipeline.linearity - INFO - LinearityStep instance created.
# 2025-09-12 21:39:57,538 - stpipe.ExposurePipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2025-09-12 21:39:57,539 - stpipe.ExposurePipeline.rampfit - INFO - RampFitStep instance created.
# 2025-09-12 21:39:57,539 - stpipe.ExposurePipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2025-09-12 21:39:57,540 - stpipe.ExposurePipeline.flatfield - INFO - FlatFieldStep instance created.
# 2025-09-12 21:39:57,540 - stpipe.ExposurePipeline.photom - INFO - PhotomStep instance created.
# 2025-09-12 21:39:57,541 - stpipe.ExposurePipeline.source_catalog - INFO - SourceCatalogStep instance created.
# 2025-09-12 21:39:57,542 - stpipe.ExposurePipeline.tweakreg - INFO - TweakRegStep instance created.
# 2025-09-12 21:39:57,582 - stpipe.ExposurePipeline - INFO - Step ExposurePipeline running with args ('../data/r0000101001001001001_0001_wfi01_uncal.asdf',).
# 2025-09-12 21:39:57,589 - stpipe.ExposurePipeline - INFO - Step ExposurePipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: None
#   output_ext: .asdf
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: cal
#   search_output_file: True
#   input_dir: ''
#   save_l1_wcs: False
#   steps:
#     dq_init:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .asdf
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     saturation:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .asdf
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     refpix:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .asdf
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       remove_offset: True
#       remove_trends: True
#       cosine_interpolate: True
#       fft_interpolate: True
#     linearity:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .asdf
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dark_current:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .asdf
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       dark_output: None
#     rampfit:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .asdf
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: rampfit
#       search_output_file: True
#       input_dir: ''
#       algorithm: ols_cas22
#       save_opt: False
#       use_ramp_jump_detection: True
#       threshold_intercept: None
#       threshold_constant: None
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .asdf
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     flatfield:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .asdf
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       include_var_flat: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .asdf
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     source_catalog:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .asdf
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: cat
#       search_output_file: True
#       input_dir: ''
#       bkg_boxsize: 1000
#       kernel_fwhm: 2.0
#       snr_threshold: 3.0
#       npixels: 25
#       deblend: False
#       fit_psf: True
#       forced_segmentation: ''
#     tweakreg:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .asdf
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       use_custom_catalogs: False
#       catalog_format: ascii.ecsv
#       catfile: ''
#       catalog_path: ''
#       enforce_user_order: False
#       expand_refcat: False
#       minobj: 15
#       searchrad: 2.0
#       use2dhist: True
#       separation: 1.0
#       tolerance: 0.7
#       fitgeometry: rshift
#       nclip: 3
#       sigma: 3.0
#       abs_refcat: GAIADR3
#       save_abs_catalog: False
#       abs_minobj: 15
#       abs_searchrad: 6.0
#       abs_use2dhist: True
#       abs_separation: 1.0
#       abs_tolerance: 0.7
#       abs_fitgeometry: rshift
#       abs_nclip: 3
#       abs_sigma: 3.0
#       update_source_catalog_coordinates: False
#       save_l1_wcs: True
#       vo_timeout: 120.0
# 2025-09-12 21:39:57,649 - stpipe.ExposurePipeline - INFO - Prefetching reference files for dataset: 'r0000101001001001001_0001_wfi01_uncal.asdf' reftypes = ['dark', 'distortion', 'flat', 'gain', 'linearity', 'mask', 'photom', 'readnoise', 'refpix', 'saturation']
# 2025-09-12 21:39:57,986 - stpipe.ExposurePipeline - INFO - Prefetch for DARK reference file is '/grp/crds/cache/references/roman/roman_wfi_dark_1700.asdf'.
# 2025-09-12 21:39:58,006 - stpipe.ExposurePipeline - INFO - Prefetch for DISTORTION reference file is '/grp/crds/cache/references/roman/roman_wfi_distortion_0064.asdf'.
# 2025-09-12 21:39:58,025 - stpipe.ExposurePipeline - INFO - Prefetch for FLAT reference file is '/grp/crds/cache/references/roman/roman_wfi_flat_0200.asdf'.
# 2025-09-12 21:39:58,045 - stpipe.ExposurePipeline - INFO - Prefetch for GAIN reference file is '/grp/crds/cache/references/roman/roman_wfi_gain_0238.asdf'.
# 2025-09-12 21:39:58,068 - stpipe.ExposurePipeline - INFO - Prefetch for LINEARITY reference file is '/grp/crds/cache/references/roman/roman_wfi_linearity_0314.asdf'.
# 2025-09-12 21:39:58,089 - stpipe.ExposurePipeline - INFO - Prefetch for MASK reference file is '/grp/crds/cache/references/roman/roman_wfi_mask_0078.asdf'.
# 2025-09-12 21:39:58,109 - stpipe.ExposurePipeline - INFO - Prefetch for PHOTOM reference file is '/grp/crds/cache/references/roman/roman_wfi_photom_0097.asdf'.
# 2025-09-12 21:39:58,129 - stpipe.ExposurePipeline - INFO - Prefetch for READNOISE reference file is '/grp/crds/cache/references/roman/roman_wfi_readnoise_0816.asdf'.
# 2025-09-12 21:39:58,161 - stpipe.ExposurePipeline - INFO - Prefetch for REFPIX reference file is '/grp/crds/cache/references/roman/roman_wfi_refpix_0045.asdf'.
# 2025-09-12 21:39:58,183 - stpipe.ExposurePipeline - INFO - Prefetch for SATURATION reference file is '/grp/crds/cache/references/roman/roman_wfi_saturation_0244.asdf'.
# 2025-09-12 21:39:58,204 - romancal.pipeline.exposure_pipeline - INFO - Starting Roman exposure calibration pipeline ...
# 2025-09-12 21:39:58,350 - stpipe.ExposurePipeline.dq_init - INFO - Step dq_init running with args (<roman_datamodels.datamodels._datamodels.ScienceRawModel object at 0x15e467b10>,).
# 2025-09-12 21:39:58,582 - romancal.dq_init.dq_init_step - INFO - Flagging rows from: -999999 to -999999 as affected by guide window read
# 2025-09-12 21:40:27,108 - stpipe.ExposurePipeline.dq_init - INFO - Step dq_init done
# 2025-09-12 21:40:27,150 - stpipe.ExposurePipeline.saturation - INFO - Step saturation running with args (<roman_datamodels.datamodels._datamodels.RampModel object at 0x15ddf51d0>,).
# 2025-09-12 21:40:27,152 - romancal.saturation.saturation_step - INFO - Using SATURATION reference file: /grp/crds/cache/references/roman/roman_wfi_saturation_0244.asdf
# 2025-09-12 21:41:25,725 - stcal.saturation.saturation - INFO - Detected 405 saturated pixels
# 2025-09-12 21:41:25,774 - stcal.saturation.saturation - INFO - Detected 66812 A/D floor pixels
# 2025-09-12 21:41:25,792 - stpipe.ExposurePipeline.saturation - INFO - Step saturation done
# 2025-09-12 21:41:25,969 - stpipe.ExposurePipeline.refpix - INFO - Step refpix running with args (<roman_datamodels.datamodels._datamodels.RampModel object at 0x15ddf51d0>,).
# /opt/anaconda3/envs/roman-data-workshop-env/lib/python3.11/site-packages/romancal/refpix/data.py:398: RuntimeWarning: invalid value encountered in divide
#   kern = (cov / mask_conv).reshape(rows, columns)
# 2025-09-12 21:44:23,747 - stpipe.ExposurePipeline.refpix - INFO - Step refpix done
# 2025-09-12 21:44:23,788 - stpipe.ExposurePipeline.linearity - INFO - Step linearity running with args (<roman_datamodels.datamodels._datamodels.RampModel object at 0x15ddf51d0>,).
# 2025-09-12 21:44:23,942 - romancal.linearity.linearity_step - INFO - Using LINEARITY reference file: /grp/crds/cache/references/roman/roman_wfi_linearity_0314.asdf
# 2025-09-12 21:48:45,544 - stpipe.ExposurePipeline.linearity - INFO - Step linearity done
# 2025-09-12 21:48:45,589 - stpipe.ExposurePipeline.rampfit - INFO - Step rampfit running with args (<roman_datamodels.datamodels._datamodels.RampModel object at 0x15ddf51d0>,).
# 2025-09-12 21:48:45,810 - romancal.ramp_fitting.ramp_fit_step - INFO - Using READNOISE reference file: /grp/crds/cache/references/roman/roman_wfi_readnoise_0816.asdf
# 2025-09-12 21:48:47,099 - romancal.ramp_fitting.ramp_fit_step - INFO - Using GAIN reference file: /grp/crds/cache/references/roman/roman_wfi_gain_0238.asdf
# 2025-09-12 21:48:48,145 - romancal.ramp_fitting.ramp_fit_step - INFO - Jump detection as part of ramp fitting is enabled.
# 2025-09-12 21:49:50,093 - stpipe.ExposurePipeline.rampfit - INFO - Step rampfit done
# 2025-09-12 21:49:50,148 - stpipe.ExposurePipeline.dark_current - INFO - Step dark_current running with args (<roman_datamodels.datamodels._datamodels.ImageModel object at 0x15d5ab6d0>,).
# 2025-09-12 21:49:50,316 - romancal.dark_current.dark_current_step - INFO - Using DARK reference file: /grp/crds/cache/references/roman/roman_wfi_dark_1700.asdf
# 2025-09-12 21:51:23,130 - stpipe.ExposurePipeline.dark_current - INFO - Step dark_current done
# 2025-09-12 21:51:23,179 - stpipe.ExposurePipeline.assign_wcs - INFO - Step assign_wcs running with args (<roman_datamodels.datamodels._datamodels.ImageModel object at 0x15d5ab6d0>,).
# 2025-09-12 21:51:23,180 - romancal.assign_wcs.assign_wcs_step - INFO - reftype, distortion
# 2025-09-12 21:51:23,336 - romancal.assign_wcs.assign_wcs_step - INFO - Using reference files: {'distortion': '/grp/crds/cache/references/roman/roman_wfi_distortion_0064.asdf'} for assign_wcs
# 2025-09-12 21:51:23,420 - romancal.assign_wcs.pointing - WARNING - Given velocity aberration scale -999999
# 2025-09-12 21:51:23,421 - romancal.assign_wcs.pointing - WARNING - Velocity aberration scale must be a positive number. Setting to 1.0
# 2025-09-12 21:51:23,423 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  269.986945918 65.974265029 269.986740075 66.097228483 269.676782843 66.097195543 269.680114359 65.974342013
# 2025-09-12 21:51:23,424 - romancal.assign_wcs.utils - INFO - S_REGION VALUES: POLYGON ICRS  269.986945918 65.974265029 269.986740075 66.097228483 269.676782843 66.097195543 269.680114359 65.974342013
# 2025-09-12 21:51:23,424 - romancal.assign_wcs.utils - INFO - Update S_REGION to POLYGON ICRS  269.986945918 65.974265029 269.986740075 66.097228483 269.676782843 66.097195543 269.680114359 65.974342013
# 2025-09-12 21:51:23,425 - stpipe.ExposurePipeline.assign_wcs - INFO - Step assign_wcs done
# 2025-09-12 21:51:23,470 - stpipe.ExposurePipeline.flatfield - INFO - Step flatfield running with args (<roman_datamodels.datamodels._datamodels.ImageModel object at 0x15d5ab6d0>,).
# 2025-09-12 21:52:52,894 - stpipe.ExposurePipeline.flatfield - INFO - Step flatfield done
# 2025-09-12 21:52:52,936 - stpipe.ExposurePipeline.photom - INFO - Step photom running with args (<roman_datamodels.datamodels._datamodels.ImageModel object at 0x15d5ab6d0>,).
# 2025-09-12 21:52:53,141 - romancal.photom.photom - INFO - photmjsr value: 0.736781
# 2025-09-12 21:52:53,141 - romancal.photom.photom - INFO - uncertainty value: 0.0286641
# 2025-09-12 21:52:53,143 - stpipe.ExposurePipeline.photom - INFO - Step photom done
# 2025-09-12 21:52:53,202 - stpipe.ExposurePipeline.source_catalog - INFO - Step source_catalog running with args (<roman_datamodels.datamodels._datamodels.ImageModel object at 0x15d5ab6d0>,).
# 2025-09-12 21:52:53,239 - romancal.source_catalog.source_catalog_step - INFO - Using ePSF reference file: /grp/crds/cache/references/roman/roman_wfi_epsf_0080.asdf
# 2025-09-12 21:52:55,215 - romancal.source_catalog.source_catalog_step - INFO - Calculating and subtracting background
# 2025-09-12 21:52:57,321 - romancal.source_catalog.source_catalog_step - INFO - Creating detection image
# 2025-09-12 21:52:58,360 - romancal.source_catalog.source_catalog_step - INFO - Detecting sources
# 2025-09-12 21:52:59,878 - romancal.source_catalog.detection - INFO - Detected 110 sources
# 2025-09-12 21:52:59,879 - romancal.source_catalog.source_catalog_step - INFO - Creating source catalog
# 2025-09-12 21:52:59,924 - romancal.source_catalog.source_catalog - INFO - Calculating segment properties
# 2025-09-12 21:53:00,167 - romancal.source_catalog.source_catalog - INFO - Calculating aperture photometry
# 2025-09-12 21:53:00,219 - romancal.source_catalog.source_catalog - INFO - Calculating DAOFind properties
# 2025-09-12 21:53:00,369 - romancal.source_catalog.source_catalog - INFO - Calculating nearest neighbor properties
# 2025-09-12 21:53:00,370 - romancal.source_catalog.source_catalog - INFO - Calculating PSF photometry
# 2025-09-12 21:53:18,338 - stpipe.ExposurePipeline.source_catalog - INFO - Saved model in r0000101001001001001_0001_wfi01_segm.asdf
# 2025-09-12 21:53:19,125 - numexpr.utils - INFO - NumExpr defaulting to 10 threads.
# 2025-09-12 21:53:19,433 - stpipe.ExposurePipeline.source_catalog - INFO - Saved model in r0000101001001001001_0001_wfi01_cat.parquet
# 2025-09-12 21:53:19,522 - stpipe.ExposurePipeline.source_catalog - INFO - Step source_catalog done
# 2025-09-12 21:53:19,579 - stpipe.ExposurePipeline.tweakreg - INFO - Step tweakreg running with args (<romancal.datamodels.library.ModelLibrary object at 0x15e31b450>,).
# 2025-09-12 21:53:19,580 - romancal.tweakreg.tweakreg_step - INFO - Number of image groups to be aligned: 1.
# 2025-09-12 21:53:19,580 - romancal.tweakreg.tweakreg_step - INFO - Image groups:
# 2025-09-12 21:53:19,580 - romancal.tweakreg.tweakreg_step - INFO -   00001010010010010010001
# 2025-09-12 21:53:19,580 - romancal.tweakreg.tweakreg_step - INFO - All source catalogs will be saved to: /Users/phuwe/src/roman/roman-data-workshop/05-Intro_Roman_Pipeline
# 2025-09-12 21:53:19,700 - romancal.tweakreg.tweakreg_step - INFO - Detected 110 sources in r0000101001001001001_0001_wfi01_uncal.asdf.
# 2025-09-12 21:53:20,260 - tweakwcs.imalign - INFO -
# 2025-09-12 21:53:20,260 - tweakwcs.imalign - INFO - ***** tweakwcs.imalign.align_wcs() started on 2025-09-12 21:53:20.260364
# 2025-09-12 21:53:20,260 - tweakwcs.imalign - INFO -       Version 0.8.11
# 2025-09-12 21:53:20,261 - tweakwcs.imalign - INFO -
# 2025-09-12 21:53:20,313 - tweakwcs.imalign - INFO - Aligning image catalog 'GROUP ID: 987654' to the reference catalog.
# 2025-09-12 21:53:20,338 - tweakwcs.matchutils - INFO - Matching sources from 'r0000101001001001001_0001_wfi01_uncal' catalog with sources from the reference 'GAIADR3' catalog.
# 2025-09-12 21:53:20,338 - tweakwcs.matchutils - INFO - Computing initial guess for X and Y shifts...
# 2025-09-12 21:53:20,339 - tweakwcs.matchutils - INFO - Found initial X and Y shifts of 0.01183, 0.01084 (arcsec) with significance of 109 and 110 matches.
# 2025-09-12 21:53:20,340 - tweakwcs.wcsimage - INFO - Found 109 matches for 'GROUP ID: 987654'...
# 2025-09-12 21:53:20,340 - tweakwcs.linearfit - INFO - Performing 'rshift' fit
# 2025-09-12 21:53:20,341 - tweakwcs.wcsimage - INFO - Computed 'rshift' fit for GROUP ID: 987654:
# 2025-09-12 21:53:20,341 - tweakwcs.wcsimage - INFO - XSH: -0.000645019  YSH: 0.000227091    ROT: -2.60668e-05    SCALE: 1
# 2025-09-12 21:53:20,341 - tweakwcs.wcsimage - INFO -
# 2025-09-12 21:53:20,342 - tweakwcs.wcsimage - INFO - FIT RMSE: 0.00119435   FIT MAE: 0.00103742
# 2025-09-12 21:53:20,342 - tweakwcs.wcsimage - INFO - Final solution based on 107 objects.
# 2025-09-12 21:53:20,362 - tweakwcs.imalign - INFO -
# 2025-09-12 21:53:20,363 - tweakwcs.imalign - INFO - ***** tweakwcs.imalign.align_wcs() ended on 2025-09-12 21:53:20.362829
# 2025-09-12 21:53:20,363 - tweakwcs.imalign - INFO - ***** tweakwcs.imalign.align_wcs() TOTAL RUN TIME: 0:00:00.102465
# 2025-09-12 21:53:20,363 - tweakwcs.imalign - INFO -
# 2025-09-12 21:53:20,366 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  269.986945547 65.974265121 269.986739564 66.097228575 269.676782332 66.097195577 269.680113987 65.974342048
# 2025-09-12 21:53:20,367 - romancal.assign_wcs.utils - INFO - S_REGION VALUES: POLYGON ICRS  269.986945547 65.974265121 269.986739564 66.097228575 269.676782332 66.097195577 269.680113987 65.974342048
# 2025-09-12 21:53:20,367 - romancal.assign_wcs.utils - INFO - Update S_REGION to POLYGON ICRS  269.986945547 65.974265121 269.986739564 66.097228575 269.676782332 66.097195577 269.680113987 65.974342048
# 2025-09-12 21:53:20,368 - romancal.lib.save_wcs - INFO - Writing the WCS files...
# 2025-09-12 21:53:20,455 - stpipe.ExposurePipeline.tweakreg - INFO - Saved model in r0000101001001001001_0001_wfi01_wcs.asdf
# 2025-09-12 21:53:20,456 - stpipe.ExposurePipeline.tweakreg - INFO - Step tweakreg done
# 2025-09-12 21:53:20,456 - romancal.pipeline.exposure_pipeline - INFO - Roman exposure calibration pipeline ending...
# 2025-09-12 21:53:21,222 - stpipe.ExposurePipeline - INFO - Saved model in r0000101001001001001_0001_wfi01_cal.asdf
# 2025-09-12 21:53:21,222 - stpipe.ExposurePipeline - INFO - Step ExposurePipeline done

# %% [markdown]
# **Alternatively:**
#
# ```
# out.save(<filename.asdf>)
# ```

# %% [markdown]
# In this mode the call to `ExposurePipeline` saves the product to a file with the same root name and a suffix of **cal.asdf**.

# %% [markdown]
# #### Running individual steps
#
# Individual steps can be run in the same way. For example, running `assign_wcs` on the resultant `cal` file.
#
# All steps can be imported from a common namespace `romancal.step`. The input to each step
# is a file name or a data model and the output is a data model. Data models are returned in memory when running in Python.

# %%
from romancal.step import AssignWcsStep

out_model = AssignWcsStep.call('r0000101001001001001_0001_wfi01_cal.asdf')
# Out:
# 2025-09-12 21:53:21,295 - CRDS - ERROR -  Error determining best reference for 'pars-assignwcsstep'  =   No match found.
# 2025-09-12 21:53:21,295 - stpipe.AssignWcsStep - INFO - AssignWcsStep instance created.
# 2025-09-12 21:53:21,357 - stpipe.AssignWcsStep - INFO - Step AssignWcsStep running with args ('r0000101001001001001_0001_wfi01_cal.asdf',).
# 2025-09-12 21:53:21,358 - stpipe.AssignWcsStep - INFO - Step AssignWcsStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: None
#   output_ext: .asdf
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
# 2025-09-12 21:53:21,404 - romancal.assign_wcs.assign_wcs_step - INFO - reftype, distortion
# 2025-09-12 21:53:21,465 - romancal.assign_wcs.assign_wcs_step - INFO - Using reference files: {'distortion': '/grp/crds/cache/references/roman/roman_wfi_distortion_0064.asdf'} for assign_wcs
# 2025-09-12 21:53:21,500 - romancal.assign_wcs.pointing - WARNING - Given velocity aberration scale -999999
# 2025-09-12 21:53:21,501 - romancal.assign_wcs.pointing - WARNING - Velocity aberration scale must be a positive number. Setting to 1.0
# 2025-09-12 21:53:21,503 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  269.986945918 65.974265029 269.986740075 66.097228483 269.676782843 66.097195543 269.680114359 65.974342013
# 2025-09-12 21:53:21,503 - romancal.assign_wcs.utils - INFO - S_REGION VALUES: POLYGON ICRS  269.986945918 65.974265029 269.986740075 66.097228483 269.676782843 66.097195543 269.680114359 65.974342013
# 2025-09-12 21:53:21,504 - romancal.assign_wcs.utils - INFO - Update S_REGION to POLYGON ICRS  269.986945918 65.974265029 269.986740075 66.097228483 269.676782843 66.097195543 269.680114359 65.974342013
# 2025-09-12 21:53:21,505 - romancal.stpipe.core - INFO - Results used CRDS context: roman_0088.pmap
# 2025-09-12 21:53:21,506 - stpipe.AssignWcsStep - INFO - Step AssignWcsStep done

# %%
out_model.save('r002_assign_wcs.asdf')
# Out:
# PosixPath('r002_assign_wcs.asdf')

# %% [markdown]
# The calls above used reference files in CRDS. **One can pass local reference files to a step or a pipeline.** For example, running assign_wcs with a custom `distortion` file called "new_distortion.asdf" in the current directory:

# %%
out_model = AssignWcsStep.call('../data/r0000101001001001001_0001_wfi01_cal.asdf', override_distortion="../data/new_distortion.asdf")
# Out:
# 2025-09-12 21:53:22,598 - CRDS - ERROR -  Error determining best reference for 'pars-assignwcsstep'  =   No match found.
# 2025-09-12 21:53:22,598 - stpipe.AssignWcsStep - INFO - AssignWcsStep instance created.
# 2025-09-12 21:53:22,655 - stpipe.AssignWcsStep - INFO - Step AssignWcsStep running with args ('../data/r0000101001001001001_0001_wfi01_cal.asdf',).
# 2025-09-12 21:53:22,656 - stpipe.AssignWcsStep - INFO - Step AssignWcsStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: None
#   output_ext: .asdf
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
# 2025-09-12 21:53:22,702 - romancal.assign_wcs.assign_wcs_step - INFO - reftype, distortion
# 2025-09-12 21:53:22,703 - romancal.assign_wcs.assign_wcs_step - INFO - Using reference files: {'distortion': '/Users/phuwe/src/roman/roman-data-workshop/data/new_distortion.asdf'} for assign_wcs
# 2025-09-12 21:53:22,735 - romancal.assign_wcs.pointing - WARNING - Given velocity aberration scale -999999
# 2025-09-12 21:53:22,736 - romancal.assign_wcs.pointing - WARNING - Velocity aberration scale must be a positive number. Setting to 1.0
# 2025-09-12 21:53:22,749 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  269.986945918 65.974265029 269.986740075 66.097228483 269.676782843 66.097195543 269.680114359 65.974342013
# 2025-09-12 21:53:22,750 - romancal.assign_wcs.utils - INFO - S_REGION VALUES: POLYGON ICRS  269.986945918 65.974265029 269.986740075 66.097228483 269.676782843 66.097195543 269.680114359 65.974342013
# 2025-09-12 21:53:22,750 - romancal.assign_wcs.utils - INFO - Update S_REGION to POLYGON ICRS  269.986945918 65.974265029 269.986740075 66.097228483 269.676782843 66.097195543 269.680114359 65.974342013
# 2025-09-12 21:53:22,752 - romancal.stpipe.core - INFO - Results used CRDS context: roman_0088.pmap
# 2025-09-12 21:53:22,752 - stpipe.AssignWcsStep - INFO - Step AssignWcsStep done

# %% [markdown]
# #### Running from the command line
#
# DMS runs the cal pipeline using the command line interface. The general syntax is
#
# ```
# % strun romancal.pipeline.ExposurePipeline <input_file>
# ```
#
# or using an alias
#
# ```
# % strun roman_elp <input_file>
# ```

# %% [markdown]
# **Running the pipeline with local reference files**
#
# Again, the above call uses reference files stored in CRDS. To use local reference files
#
# ```
# % strun romancal.pipeline.ExposurePipeline <input_file> --steps.flat.override_flat=myflat.asdf
# ```
#
# ```
# % strun romancal.step.FlatStep <input_file> --override_flat=myflat.asdf
# ```

# %% [markdown]
# **Skipping a step in the pipeline**
#
# ```
# % strun romancal.pipeline.ExposurePipeline <input_file> --steps.linearity.skip=True
# ```

# %% [markdown]
# **List the parameters for a step**
#
# To display a list of the parameters that are accepted for a given Step class, pass the `-h` parameter, and the name of a Step class or parameter file:
#
# ```
# % strun -h romancal.step.RampFitStep
#
# usage: strun [-h] [--logcfg LOGCFG] [--verbose] [--debug] [--save-parameters SAVE_PARAMETERS]
#              [--disable-crds-steppars] [--pre_hooks] [--post_hooks] [--output_file] [--output_dir]
#              [--output_ext] [--output_use_model] [--output_use_index] [--save_results] [--skip]
#              [--suffix] [--search_output_file] [--input_dir] [--algorithm] [--save_opt] [--opt_name]
#              [--maximum_cores] [--use_ramp_jump_detection] [--threshold_intercept]
#              [--threshold_constant] [--override_readnoise] [--override_gain]
#              cfg_file_or_class [args ...]
#
# This step fits a straight line to the value of counts vs. time to determine the mean count rate for
# each pixel.
#
# positional arguments:
#   cfg_file_or_class     The configuration file or Python class to run
#   args                  arguments to pass to step
#
# options:
#   -h, --help            show this help message and exit
#   --logcfg LOGCFG       The logging configuration file to load
#   --verbose, -v         Turn on all logging messages
#   --debug               When an exception occurs, invoke the Python debugger, pdb
#   --save-parameters SAVE_PARAMETERS
#                         Save step parameters to specified file.
#   --disable-crds-steppars
#                         Disable retrieval of step parameter references files from CRDS
#   --pre_hooks           [default=list]
#   --post_hooks          [default=list]
#   --output_file         File to save output to.
#   --output_dir          Directory path for output files
#   --output_ext          Default type of output [default='.asdf']
#   --output_use_model    When saving use `DataModel.meta.filename` [default=False]
#   --output_use_index    Append index. [default=True]
#   --save_results        Force save results [default=False]
#   --skip                Skip this step [default=False]
#   --suffix              Default suffix of results [default='rampfit']
#   --search_output_file
#                         Use outputfile define in parent step [default=True]
#   --input_dir           Input directory
#   --algorithm           Algorithm to use to fit. ['ols','ols_cas22', default='ols_cas22']
#   --save_opt            Save optional output [default=False]
#   --opt_name
#   --maximum_cores       max number of processes to create
#                         ['none','quarter','half','all',default='none']
#   --use_ramp_jump_detection
#                         Use jump detection during ramp fitting [default=True]
#   --threshold_intercept
#                         Override the intercept parameter for the threshold function in the jump
#                         detection algorithm.
#   --threshold_constant
#                         Override the constant parameter for the threshold function in the jump
#                         detection algorithm.
#   --override_readnoise
#                         Override the readnoise reference file
#   --override_gain       Override the gain reference file
# ```

# %% [markdown]
# #### Calibration reference Data System (CRDS)
#
# CRDS is a Python library, set of command line programs, and family of web servers used to assign and manage the best reference files that are used to calibrate HST, JWST and Roman data.
#
# The primary function of CRDS is to assign best reference files to datasets so that they can be calibrated based upon CRDS rules.
#
# The CRDS User guide is available on the front page of the CRDS server.
#
# https://roman-crds.stsci.edu/static/users_guide/index.html

# %% [markdown]
# **Exercise:**
#
# Run the Roman Exposure Level pipeline on a Level 1 file .
#
# On the command line this is
#
# ```
# strun roman_elp r0000101001001001001_01101_0002_WFI01_uncal.asdf --steps.rampfit.save_opt=true
#
# strun romancal.ramp_fitting.RampFitStep r0000101001001001001_01101_0002_WFI01_darkcurrent.asdf --save_opt=true
#
# ```
